# %% [markdown]
# # Support Vector Machine (SVM)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
ds = pd.read_csv('/content/diabetes.csv')
X = ds.iloc[:, :-1].values
y = ds.iloc[:, -1].values

# %% [markdown]
# #First 5 columns of dataset

# %%
ds.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#Number of rows and columns
ds.shape
# Out:
# (768, 9)

# %%
#Statistical measures of ds
ds.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Get count of values in [x] column.
#Use this fxn to see if we oversampled or undersampled for dependant variable(Label).
#If dv col has no header then put col num in [x] else put col name

ds['Outcome'].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %% [markdown]
# 0 --> Not Diabetic
#
#
# 1 --> Diabetic

# %% [markdown]
# ## Splitting the ds into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Training the SVM model on the Training set

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
print("Model Accuracy_Score: ", "{:.2f}".format(accuracy_score(y_test, y_pred)))
# Out:
# [[117  13]
#  [ 25  37]]
# Model Accuracy_Score:  0.80

# %% [markdown]
# ##Making Prediction

# %%
input_data = (2,197,70,45,543,30.5,0.158,3)

#Changing input_data to numpy array
input_data_as_numpy_array = np.asarray(input_data)

#Reshape np array as we predict for one instance
## Model expects 168 points so we reshape it to tell it to expect 1 value(input_data)
input_data_reshaped = input_data_as_numpy_array.reshape(1, -1)

#We can`t use the data as is because we standardised the data so
#Standardize the input_data
std_data = sc.transform(input_data_reshaped)


#Feed Standardized data to model
prediction = classifier.predict(std_data)
print(prediction)

if(prediction[0] == 0 ):
  print("Patient is not Diabetic.")
else:
  print("Patient is Diabetic.")
# Out:
# [1]
# Patient is Diabetic.
